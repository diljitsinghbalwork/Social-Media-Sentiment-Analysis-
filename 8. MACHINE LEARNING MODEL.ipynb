# %%
import pandas as pd
from textblob import TextBlob
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVR
from sklearn.metrics import classification_report, accuracy_score

nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

def preprocess_tweet(tweet):
    tweet = re.sub(r"(https?:\/\/\S+|[^A-Za-z0-9\s]+)", "", tweet.lower())
    words = tweet.split()
    filtered_words = [word for word in words if word not in stop_words]
    return " ".join(filtered_words)

def polarity_to_class(polarity):
    if -1 <= polarity < -0.34:
        return "negative"
    elif -0.34 <= polarity <= 0.34:
        return "neutral"
    else:
        return "positive"

# Load the top 100 words data
biden = pd.read_csv("Biden_Word_Polarity.csv")
putin = pd.read_csv("Putin_Word_Polarity.csv")
zelenskyy = pd.read_csv("Zelenskyy_Word_Polarity.csv")
xijinping = pd.read_csv("Xijinping_Word_Polarity.csv")

# Drop rows with missing values
biden.dropna(inplace=True)
putin.dropna(inplace=True)
zelenskyy.dropna(inplace=True)
xijinping.dropna(inplace=True)

# Combine the top 100 words data for all politicians and remove duplicates
all_top_words = pd.concat([biden, putin, zelenskyy, xijinping], ignore_index=True).drop_duplicates(subset=["Word"])

# Create the TfidfVectorizer
vectorizer = TfidfVectorizer(vocabulary=all_top_words["Word"].tolist(), ngram_range=(1, 1))

# Prepare the top 100 words data for training
X_train = vectorizer.fit_transform(all_top_words["Word"]).toarray()
y_train = all_top_words["Polarity"]

# Train an SVM regression model on the top 100 words data
model = SVR()
model.fit(X_train, y_train)

# Load the tweet data for Modi and Trudeau
modi_tweets = pd.read_csv("Filtered_Modi_CSV.csv")["Text"]
trudeau_tweets = pd.read_csv("Filtered_Trudeau_CSV.csv")["Text"]

# Drop rows with missing values
modi_tweets.dropna(inplace=True)
trudeau_tweets.dropna(inplace=True)

# Preprocess all tweets
modi_tweets = modi_tweets.apply(preprocess_tweet)
trudeau_tweets = trudeau_tweets.apply(preprocess_tweet)

# Create a binary feature matrix for the Modi and Trudeau tweets
X_test = vectorizer.transform(pd.concat([modi_tweets, trudeau_tweets], ignore_index=True)).toarray()

# Predict sentiment polarity of the Modi and Trudeau tweets
y_pred = model.predict(X_test)

# Convert the predicted polarity values to sentiment classes
y_pred_classes = [polarity_to_class(polarity) for polarity in y_pred]

# Print the sentiment polarity predictions for each tweet
for i, tweet in enumerate(pd.concat([modi_tweets, trudeau_tweets], ignore_index=True)):
    print(f"Tweet: {tweet}")
    print(f"Predicted Polarity: {y_pred[i]}")
    print(f"Predicted Sentiment Class: {y_pred_classes[i]}\n")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Diljit
# [nltk_data]     Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Tweet: vivekgramaswamy mini modi one trick pony actual policy positions lifted team trump
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: 11 pm modis roadshow span 11 1 pm 101 km 4 pm 10 pm 265 km
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: 9 meanwhile prime minister narendra modi conduct 366 km roadshow bengaluru may 6
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: bjp4tamilnadu go back modi modi gedi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: upadhyayabhii ab yeh patrkarita zyada din nhi chalne wali abki baar 2024 ke baad tumhari baari sootr batate hen modi sarkar media trail hindu muslim karne per jail men dalne ki tayyari
# Predicted Polarity: 3.937309353297877e-05
# Predicted Sentiment Class: neutral
#
# Tweet: manipur burning help mary kom sought help pm modi late night
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: alishaabdullah pmoindia narendramodi bjp4india qatardutyfree sorry lost least 2 exchange fees always choose foreign currency option swipe card overseas unless want burn precious money singing modi bhajan
# Predicted Polarity: -0.21226024066919644
# Predicted Sentiment Class: neutral
#
# Tweet: cldonline kushalsonavane emmanuelmacron narendramodi allez vivre en ukraine 10 000 prisonniers franaisstalag 325banderas azov das reicht galicie sont glorifiecrivez en franais madameje dteste macronsoldat amricainsmodidevrait faire attention tratres amricains
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: voteoutbjp modihataodeshbachao karnatakaassemblyelections2023 modifailsindia
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: starboy2079 s97nishu bhawanakishore kind actions parties like aap tmc brings press freedom index modi gets blame
# Predicted Polarity: 0.4998905644436065
# Predicted Sentiment Class: positive
#
# Tweet: trueindian0 hindu rastra ghosit karo modi ji ab time aagya h ji
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modi rss n bjp hindutuv governmen india become country institutionalised riot system irs wherein riots prepared activated sustained explanatory justifications manipurvoilence manipuronfire saturdaymorning modihataodeshbachao
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: navjeetjha1 moseva niiravmodi people like adani modi evading income taxes huge sum taxes looted middle amp lower middle class direct indirect taxes much per litter petrol vegetable seller paying tax much per cylinder poor family paying tax
# Predicted Polarity: 0.12698895813520686
# Predicted Sentiment Class: neutral
#
# Tweet: sheetalpronamo using opportunity provided bjp clear agenda provided ready mob even ganapati festival sloganeering rss modi brahmin hindu pro azadi
# Predicted Polarity: 0.059630337600382555
# Predicted Sentiment Class: neutral
#
# Tweet: aditiyadavfan modi ji apke papa
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: b5001001101 gone days modi tsunamai wave hardly people excited glimpse bharat jodo yatra seen tsunami people
# Predicted Polarity: -0.1916644962892394
# Predicted Sentiment Class: neutral
#
# Tweet: arvindkejriwal akj sahab aakon delhi wale aur punjab mein khalistani hi jhel sakte hain nahi aap kisi layak nahi aapki gandi rajneeti chalane ka pahiya modi modi aur sirf modi hain
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: faridkhan accha laga pm modi ne afridi ki jala ke rakh di
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: narendramodi go back modi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: reasons watch thekeralastory ratings kerala story ndtv 055 india today 15 indian express 15 modi 55
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: aasaithilipan modisangi007 trbrajaa dmkitwing itwreports udhaystalin mkstalin paramporul kparanjothi1976
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: narendramodi aaj k sadi v rally prachar yadi modi ji ki jagah indira gandhi ji hoti ab tk rally sally par ban lga chuki hoti ak desh ak chunav v lagu ho gya hota
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ibhardwajhemant thanks sharing details due vision modi ji jai bhole nath ji thanks
# Predicted Polarity: 0.07219195433727427
# Predicted Sentiment Class: neutral
#
# Tweet: modi h mumkin h
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: vivekagnihotri states bjp trying win seats hence truckloads modistyle lies happening
# Predicted Polarity: 0.6999277671742815
# Predicted Sentiment Class: positive
#
# Tweet: kashifarsalaan modi ha mumkin ha ye jhalak ha pura des jalega vote ke liye des nafarat bant di modi kanun ka raj nahi ha
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: aapdelhi arvindkejriwal aise dialogue roz marta hai koi seriously nahi leta inko siwaye modi ki kedelhi wale bhi usi din ka wait kar rahe jab tumhare saath waise hoga jaise tum bol rahe jai maa saraswati aaj iski zubaan pe bath jana
# Predicted Polarity: -0.23333116302875176
# Predicted Sentiment Class: neutral
#
# Tweet: modisadam
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: zoobear modi ji amp co soo busy
# Predicted Polarity: 0.021356337416515447
# Predicted Sentiment Class: neutral
#
# Tweet: sun may raise west modi never revoke article 370 matter much cry
# Predicted Polarity: 0.10000217088734392
# Predicted Sentiment Class: neutral
#
# Tweet: halakki vokkaliga tribe felt proud padma awardees meeting pm modi karnataka via namo app
# Predicted Polarity: 0.7002625886034384
# Predicted Sentiment Class: positive
#
# Tweet: bacha bacha janata hai modi hi hamari aakhari umid hai
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: bbhuttozardari sun may raise west modi never revoke article 370 matter much cry
# Predicted Polarity: 0.10000217088734392
# Predicted Sentiment Class: neutral
#
# Tweet: dakhsinroy ashishbadshah sardesairajdeep bbhuttozardari yeah biggest clowns jail good times amit shah killed judge got chinta na kar dubara modi shah ko tihar ke chakkar katwaenge
# Predicted Polarity: 0.16936735938717937
# Predicted Sentiment Class: neutral
#
# Tweet: rohinisgh hence vote modi kaise bhi ensure rohini doesnt get 3 bhk flat scamgress
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: bjp4india arey modi badkav kaiku ull banar pablic
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: supriyasule pawarspeaks ncpspeaks would pm 20 years back modi amit shah would emerged cong suffering today due called tn northern state kamraj great politician always working people long live pawar saheb great man
# Predicted Polarity: 0.3906862922572628
# Predicted Sentiment Class: positive
#
# Tweet: news24tvchannel modi ki raani tum modi se bada koe jhootha nhi desh dam h aadani ke mudda pe bol corona time pm care fund pe bol
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: akhilgo69882941 kapoorjaiswal5 deependershooda beta kuj bolte rho ab jb tere modi k chutad pad diye election se phle kyu mangi maafi election tk wait krda frr pta chlta rhi ki bat waha kisaano ko gribi rhna acha lgta h tere jaise chutiya ko bss 5 killo rasn cahaye employment nhi chahiye
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: jsbowen drianhall india amp china accounting 80 active coal projects new delhi wedging beijing would bonus draft approved fed cabinet chaired pm modi would make china major economy open fresh requests add significant new coalfired capacity
# Predicted Polarity: 0.10690054312569647
# Predicted Sentiment Class: neutral
#
# Tweet: supriyashrinate kharge level confidence modi ji givennot rant italian familysad sadjaishankar
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: suryapsinghias tuche ias tu kitna bhe ro le par sun ayga modi fir next 5 year rona padega ese twitter par
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: voiceofind1 always pm narendra modi modi isnt prime minister also heart india pmmodi pmoindia
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: mukeshmarda wont end end modi sarkar karnataka beginning remaining mp amp haryana already supporting congress bjp sacrifice every state except gujarat gujarat files
# Predicted Polarity: 0.15000217097475868
# Predicted Sentiment Class: neutral
#
# Tweet: ikaushikvekaria amitshah crpaatil jpnadda narendramodi ratnakar273 bjp4india bjp4gujarat nalinkateel bjp4karnataka mansukhmandviya modi mumkin hai
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: scorpiondoc3 ashishbadshah sardesairajdeep bbhuttozardari better hitler modis circus
# Predicted Polarity: 0.4000021714118297
# Predicted Sentiment Class: positive
#
# Tweet: dumbnumb modi ki bhi hen
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ramtyagihindu bajrangpunia geetaphogat sakshimalik phogatvinesh sangeetaphogat anti modi protest pro test
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: mediacellppp bbhuttozardari indiatoday sun may raise west article 370 revoked modi matter much cry
# Predicted Polarity: 0.10000217088734392
# Predicted Sentiment Class: neutral
#
# Tweet: modi g child gets cut wires godi ji remain fakir man pick bag walk modi jawab
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: singhjagender newsschaudhry singh ji aap retired aadmi ho aapne sab dekha hai phir kyu aap bhi andhbhakto jaisi baate karte ho kya modi ji kabhi majar nahi gaye kya modi ji ne chaddar nahi chadai baat karo muddo per aaj manipur jal raha hai modi hi election main busy hai
# Predicted Polarity: 0.04339781837346593
# Predicted Sentiment Class: neutral
#
# Tweet: omaltiso avidandiya modi fir lao development pao
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: see development banglore karnataka modi govt congress didnt care 65 long years
# Predicted Polarity: 0.021356337416515447
# Predicted Sentiment Class: neutral
#
# Tweet: narhandle ktrbrs konathamdileep prakashraaj pbhushan1 trbrajaa suhasinih pawankhera lambaalka srivatsayb like kcr nonsense abusive language press meets without taking bjp name modi name cant win elections telangana example munugodu
# Predicted Polarity: 0.6999277671742815
# Predicted Sentiment Class: positive
#
# Tweet: vidyakrishnan women pillar modis nationwide support
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: vinaymishraaap think modi responsible rather think person came aam aadmi illegal things conscience think objectively
# Predicted Polarity: -0.14534819671766203
# Predicted Sentiment Class: neutral
#
# Tweet: swamy39 chances 1 person brought idol come interrupted without waiting turn 2 modi said thanks gift keep aside 3 person brought purpose 4 modi said early wait sec praan pratishta done offences
# Predicted Polarity: 0.10000217088734392
# Predicted Sentiment Class: neutral
#
# Tweet: opinion unprecedented increase coal production modi governments tenure import decreased via namo app
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: rai radio 2 lunatici scudetto napoli maradona ho cercato tutti modi di stargli vicino con le buone e le cattive
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: antoniogm kunalmodi spindlxyz assign credit channel within cpv paradigm common problem multitouch attribution channel responsible user ltv
# Predicted Polarity: -0.048043563626099656
# Predicted Sentiment Class: neutral
#
# Tweet: modi u r imposing hindi india time narendramodi wants trade russia rupee russia interested business rupee bcoz per statement sergeilavrov banks accounts r hindi
# Predicted Polarity: 0.09965494866451502
# Predicted Sentiment Class: neutral
#
# Tweet: kumar1975rajesh madam dar dil hai modi shah kya karenge
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: kirtiazaad azaad g kuch b kar lo aaega modi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: chandrumlpt modisangi007 maayonism trbrajaa dmkitwing itwreports udhaystalin mkstalin paramporul kparanjothi1976
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: tejasvisurya dude get life mp ur duties u prefer shows boot licking culture u grew policy party good public could understood chat chat chat modi kee song karnatakacom bangalorebuzz
# Predicted Polarity: 0.6002625884286094
# Predicted Sentiment Class: positive
#
# Tweet: supriyashrinate kaun hai ye mahilaa itni chat rahi hai rahul ki aram se madam kabhi reply bhi dekh liya karo tumare liye hum hi log kafi haikaha aap modi nadda shah se bhidne jaa rahi haiwo log bhigoge ke marenge
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: zoobear narendra modi doesnt need certification isis sympathizer
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ranaayyub modi wise man
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: nessmonster007 themangoindian simple bjp cant number 1 rattling tdp 2 years later pick mantletdp days jus like inc gets trap 2018 jagan trap fight modinow instead taking ycp fighting bjpdont want 1
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: halakki vokkaliga tribe felt proud padma awardees meeting pm modi karnataka via namo app
# Predicted Polarity: 0.7002625886034384
# Predicted Sentiment Class: positive
#
# Tweet: news24tvchannel modi enough cant make fool public public understands vote gymics
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: shireenmazari1 showing full loyalty support modi led india government
# Predicted Polarity: 0.2500393735306048
# Predicted Sentiment Class: neutral
#
# Tweet: tw 5 years modi govt plans meet pharma medtech industry discuss concerns pricing dpco nppp rulebooks pharmaceutical medical device industry regulates availability pricing medicines
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: antoniogm spindlxyz kunalmodi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: axhelix lisa90135765 non volevo dibattere sui modi efficaci di rispondere se dovesse accadere nella vita reale ponevo lattenzione su come pervasivamente si denigrino gli uomini ogni occasione
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: tejasvisurya narendramodi soooooopermahaathmaa modi ji heart always welcome support strengthen mahathmaa modi ji converging modi jis vishwa kalyan thought processjai hindjai shree ram
# Predicted Polarity: 0.7000021719363164
# Predicted Sentiment Class: positive
#
# Tweet: 13 karnatakaassemblyelection narendramodi modiroadshow bengaluru
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: news24tvchannel 2014 modi delivered excellent speeches attract people votes ache din 15 lakh chokidar 2 crorer jobs give 1 chance check report card year punish modi said videshi dhan waste talking bjp indian understand vote value
# Predicted Polarity: 0.8870742417096176
# Predicted Sentiment Class: positive
#
# Tweet: arvindkejriwal aap kehte corona ki vaccine dene 100 saal lag jayengehaan 100 saal lag jaate agar apke jaise koi pm hota koi modi issi wajaa se sabko aur bahar import kari vaccine sirf 6 months bolte sab hai karte sirf modi hai modi hai toh sab mumkin hai
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ranvijaylive ayejut mat bol main wahi tha muskil se 12 hajar log hi waha aur pata nhi modi ji kise haat hila rahe
# Predicted Polarity: 0.06666883749573466
# Predicted Sentiment Class: neutral
#
# Tweet: one asked fr hang death demanded fr proper enquiry justice cant even capable far antiprtsters isnt fir copy public fir registered isnt arrested hasnt done anything go frenquiry ur modi chathi open
# Predicted Polarity: 0.05961224114639502
# Predicted Sentiment Class: neutral
#
# Tweet: ashoswai five special forces soldiers killed action rajouri sector yesterday condolences tweets narendra modi 0 rajnath singh 0 amit shah 0 smriti irani 0 jp nadda 0 welcome hamare jawaan siachen main khade hai lies
# Predicted Polarity: 0.24620156405395513
# Predicted Sentiment Class: neutral
#
# Tweet: ani zhukti hai duniya zhukane wala caheye pre 2014 india mms jst requested fr peace talks wit pak kashmir post 2014 forget side land nw qll abt pok tables hv turned wont surprised day modi ji choose occupy pok
# Predicted Polarity: 0.021356337416515447
# Predicted Sentiment Class: neutral
#
# Tweet: sureshchavhanke uttrakhand mahoday jo waha demographic change ho rahaatikraman ho raha majaro ke naam pe modi gov bhi kuch nahi us pe kya aap logo ko jagruk karenge
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modi desperate instead talking karnataka kannadigas talking every nonsense thing karnatakaassemblyelection2023
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: antoniogm spindlxyz kunalmodi writing docs gitbook crushing beers chad movements
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: scmpnews levelheaded modi administration may see need take hard line beijing disputed border also know well take heat
# Predicted Polarity: -0.19166449628923996
# Predicted Sentiment Class: neutral
#
# Tweet: roopalisriv modi era manmohan era significant differences democracy need approachable leader whats right self declared king second may seem strong evolved society chosen democracy lets think whos evolved
# Predicted Polarity: 0.26898385140427694
# Predicted Sentiment Class: neutral
#
# Tweet: arvindharmapuri dhonga badkav modi givvi ami jai jai hanuman givve world lo fast papuleshan lo india
# Predicted Polarity: 0.10000217088734392
# Predicted Sentiment Class: neutral
#
# Tweet: handsomey brucearthur justintrudeau waiting david johnston finish work everyone else also fi china russia gop backing convoy harper rubbing elbows despots like modi orban
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ayusnl60 shubhamshuklamp ye kaun se kanun hai madhar jat ki jiska kabja uski jameenkal ko teri behan ki cht par maine kabja kar liya kaya wo meri ho jayegee
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: antoniogm spindlxyz kunalmodi 1 1 rare one
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: jagats299 kareenakpn ravish sarkar ki galat nitiyo ka virodh krta haichahe modi ho ya congress
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: emmanuelmacron narendramodi tha priminister narendra modi best popular india
# Predicted Polarity: 0.6752987967543888
# Predicted Sentiment Class: positive
#
# Tweet: opinion unprecedented increase coal production modi governments tenure import decreased via namo app
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: hang day find involvement corruption single paisa arvindkejriwal narendramodi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: mpnavneetrana agle pm banenge matlab modi ji ke baad
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: lambaalka narendramodi narendra modi speech supreme court guidelines take action spread hatred kerala story islamphobic muslims fir must pm actress producer director awaiting asadowaisi take action
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: kiya dara narndar modi ka
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: news24tvchannel jpnadda jhuth mat faila sari dunia thu thu kar rahi hai narendra modi ke uper isiliye ko sikka jamana kehte hai sar ki namaste aulad besharm gandi nali ke reed viheen kide
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: aajtak chitraaum last ek question mar dal ke sare modi ke chamche bjp ke baat karta haidalle aise questions mark dalke hum bhi bohot kuchh keh sakte hai chitraaum
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: verifeidreal swamy39 laughing matter ashok mature happened daughter would laugh sensible write someone family related issues qualities belong modi bhakths
# Predicted Polarity: 0.20000217106217297
# Predicted Sentiment Class: neutral
#
# Tweet: arvindkejriwal jhut ki bhi seema hoti hai modi ji pm hai unhone ne apni family kisi ko benefit nai diya aur ap jo bolte uska koi prooof nai hota aapki party ke mantri chor hai modi ko koi nai haata sakta woh khud aaye hai khud jayenge
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: hum apne alcanon se modi ki nangi video leak karke india ko munh torr jawab denge
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modisangi007 analmsksiththan
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: analmsksiththan modisangi007
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: randomsena je vi modi ka palto hai
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: blrnirmal bjp hope people nation better tomarrow dynamic leadership honble pm shri narendra modi ji efficient cabinet team members
# Predicted Polarity: 0.4000021714118297
# Predicted Sentiment Class: positive
#
# Tweet: tajinderbagga punjabpoliceind arvindkejriwal timesnow kidnap kahan hua tha modi shah tere baapo ne bacha liya tha
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: deepalip atullondhe bjp trying get secular votes lose even hardcore bjp supporters also would ditch modiirani etc focused stirring hindu sentiments painting picture congress promuslim last resort
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: chaosprevails zoobear aakarpatel ashoswai b5001001101 crypticmiind priainc wow brand new laid roads wish modi also visits kasavanahalli aread area badly needs roads
# Predicted Polarity: 0.036129064715069964
# Predicted Sentiment Class: neutral
#
# Tweet: iampremkurien narendramodi amitmalviya rahul spontaneous working modi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: annamalaik incindia narendramodi kids also like modi ji
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: halakki vokkaliga tribe felt proud padma awardees meeting pm modi karnataka via namo app
# Predicted Polarity: 0.7002625886034384
# Predicted Sentiment Class: positive
#
# Tweet: roflepicdon modi eshtyle
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: pm modi reacted ongoing controversy film kerala story saying movie based terror conspiracy addressing rally ballari karnataka pm modi said kerala story shows ugly truth terrorism exposes plans terrorists
# Predicted Polarity: -0.6001094374795087
# Predicted Sentiment Class: negative
#
# Tweet: anshuamethibjp newsschaudhry jab modi ji hanuman bhakti ka mukhota laga sakte hai tab
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: brown man hellbent jump queue modi sunak amp kamala maybe haley together form potent force stop sick man asia overtaking bosom buddy white man brown man feels centuries white mans rule hes white like white man
# Predicted Polarity: -0.6143579494091814
# Predicted Sentiment Class: negative
#
# Tweet: muktesharma modi ji
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: tejasvisurya future modi future tejasvi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: dr swamy39 please congress amp jaitley faction bjp keep saying 2g scam overrated amp loss notional protecting corrupt feel modi hai mumkin hai sonia hai nischit hai
# Predicted Polarity: -0.3999978299868001
# Predicted Sentiment Class: negative
#
# Tweet: riturathaur question meitehindus wearing bangles cant reciprocate till hindus dependent modi yogi ji one save dont help war knocking ur door pity running away wont stop unless responde
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: jatassociation baat shi hai bhaii ji jo galat ho karlarvaai honi chaaiye pr vha harsh chikkara jaise log modi ji ko pta ni kya kya khre ye log modi ji ko bich mai kyu laatey hai
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: pmmodi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: sardesairajdeep bbhuttozardari wow another lion india besides modi jee brilliant sir jai shankar bharat ratna
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: zioklint lisa90135765 riguarda la tavoletta basta rispondere che lei non saperla alzare sulla masturbazione ci sono altri mille modi creativi che per evito di dire
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: grande sscnapoli sapete sempre come festeggiare nel migliore dei modi guardate bene basso
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modi facist
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: mashwaniazhar eliminating modis proxies pakistan ground work laid israel west imran khan eradicated sit
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: newsschaudhry inka kya hai modi h tab tak h fir kon puchega islia ase byan karte rhte hai fir bjp aane wale nhi hai yeh wahi gass wale unte
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: aavishhkar cinemawithprd pm modi tak karnataka chunav mein film ko promote kar rahe hain bjp ka pura cell film ko social media par promote kar raha hai iski sponsored screening dikhai jaa rahi hai kai states mein aur kitna promotion chahiye
# Predicted Polarity: 0.021356337416515447
# Predicted Sentiment Class: neutral
#
# Tweet: congress nurtured amp gave shelter terror pm narendra modi karnataka ballari narendramodi bjp karnatakaelections congress
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: governments fire fire bjp modi failed india
# Predicted Polarity: -0.3999978299868001
# Predicted Sentiment Class: negative
#
# Tweet: ehsan tera hoga muz par1mohrafidrrajesh modibeautiful beatslovely lyrics melody goviral wear headphones earphones better audio copyright entertainment
# Predicted Polarity: 0.4000021714118297
# Predicted Sentiment Class: positive
#
# Tweet: zoobear kitna bhi ro lo ayega modi hi propaganda machine zoobear member peaceful puncture community
# Predicted Polarity: 0.07354651071688133
# Predicted Sentiment Class: neutral
#
# Tweet: javed0909 amitshah likewise modi castigated cow protectors vigilante typical politician guess know groups like bajrang dal amp gau raksha dals reaction civilisational attacks barbarians
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ndioneada ohh massa way mtina trop mais garabag modi niaka dioudd adouna moni mel rek walahii yalnala yallah may xolou mogn quelque soit alpha ne baisse jamais les bras yallah khar ln aldiana firdawsi si bark taha ya rabii
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ani modi bhakts dekha mitron kaise election ki rukh mod diya saara dhyaan corruption commission infrastructure aur development se hata kar bajrangbali keralafiles aur 91galiyon pe le aaya propaganda movie ka sahara lena pad raha hai roflgandhi
# Predicted Polarity: 0.04922487655748671
# Predicted Sentiment Class: neutral
#
# Tweet: aajtak jo anpad gawaar log hai wo modi ji ke pichhe pad jayenge lekin jo log sach jante hai wo murkho ki baaton mai nahi aayenge kyuki ab desh janta ko pata hai kya karna hai kya nahi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modisangi007 maayonism trbrajaa dmkitwing itwreports udhaystalin mkstalin paramporul kparanjothi1976
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: aranganathan72 rsfinter america already action rsf funded georgesoros already pumped 1 billion usd 8000 crores india need pump 10 billion usd bring modis regime
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: kerala story distracts wrestlers protest amp bjp corruption cases kerala story authenticity questionable taken deleted website accused pedophile brij bhushan investigated modi violates election rules amp politicizes kerala story india address issues
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: crazyunited10 starboy2079 ashish75757575 manishasagar18 bhawanakishore narendramodi abb iski bolti band modi dangerous politician general category
# Predicted Polarity: -0.23224736876632798
# Predicted Sentiment Class: neutral
#
# Tweet: ranvijaylive bichare rv ki halat kutton wali ho gayi hai din raat modi ke peeche sunghte hue ghumta rahata hai
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: amitbehere except brahmins anymore generally uppercaste andor rabid hindu men look yogi modi arent brahmins dont miss blink exploit religion
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: atishiaap modi 100 occupied karnataka election present noone looking government
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: sanjayazadsln chor juthy log pereshan hen modi jindabaad
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: prajavani bukali faku modi chakka irbahudu adakke tanna hendatige mane inda odsiddane ugrappa sir
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: csnkarthik indhavaainko ask modi ji tell christian nation
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: sagar4bjp west fellow mdi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: dehradun students reportedly fined listening pm modis mann ki baat parents also showed screenshot orders issued school management whatsapp group new india doesnt want listen mann ki bakwas hell listen us
# Predicted Polarity: 0.036129064715069964
# Predicted Sentiment Class: neutral
#
# Tweet: pushing code bar startup gods require spindlxyzs cto kunalmodi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: theskindoctor13 modi hai mumkin hai
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: people india seeking sc take law hand dont know comes door steps hm pm dancing karnataka indians raise voice failure modi sought sc direct intervention citizens support call law arrest hm
# Predicted Polarity: 0.021356337416514912
# Predicted Sentiment Class: neutral
#
# Tweet: prakashraaj kerala story propaganda film movie produced pmo association nddm narender damodar das modi like kashmir files create communal riots country political purposes thats
# Predicted Polarity: 2.170712515636025e-06
# Predicted Sentiment Class: neutral
#
# Tweet: general public india appeal sc manipur flaming hm dancing karnataka pm inciting bajrangi
# Predicted Polarity: 0.021356337416515447
# Predicted Sentiment Class: neutral
#
# Tweet: wht promised people manipur amp government manipur never fall modis fake promises amp fake love law amp order worsened violence erupted manipur hope peace restored state manipurisburning
# Predicted Polarity: -0.2216051344226461
# Predicted Sentiment Class: neutral
#
# Tweet: kashifarsalaan modi ji karnatka busy hain karega kon
# Predicted Polarity: 0.021356337416515447
# Predicted Sentiment Class: neutral
#
# Tweet: publictvnews bukali faku modi grampanchayati gu nalayak thuu
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ajenglish quite surprising live india unaware news local news channel reporting unfortunate boot lickers modi trolling al jazeera tweeting news local godi media even talking
# Predicted Polarity: 0.036129064715069964
# Predicted Sentiment Class: neutral
#
# Tweet: ranvijaylive chinta mat karo tukade par palane vale patalkar modi ji tweet nhi karte h vo sidhe action lete h
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: yakanna modi rally roadshow inda asta baya na
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: news24tvchannel modi ji ke bad aaega yogi ji hi yah bharat ki janata ne tay kiya hai hindu rashtra banana hai
# Predicted Polarity: -0.5999978303364565
# Predicted Sentiment Class: negative
#
# Tweet: sanggitat modi fighting hard get nobel peace prize also popularity
# Predicted Polarity: -0.19166449628923996
# Predicted Sentiment Class: neutral
#
# Tweet: modisangi007 maayonism trbrajaa dmkitwing itwreports udhaystalin mkstalin paramporul kparanjothi1976 4 4 4 4
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: india imbalanced india modi said 2014 shame voters choosing dealers
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: mamata banerjee randomly talks unrelated historical figures furthering rumours modi govt removing mughal history textbooks
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet:
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: indiapakistan talks manmohan singh seek final settlement pakistan jammu kashmir different earlier initiatives significant manner singh wanted solution entail redrawing borders
# Predicted Polarity: 0.27503937357431185
# Predicted Sentiment Class: neutral
#
# Tweet: ptinews usp epic sop toolkit modi eshtyle policy bjp eshtyle policy
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: tejasvisurya sir please bring modi ji koramangala must visit epic monument ejipura flyover narendramodi 40percentbjpsarkara
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: vinaysreeni bbmpcomm bjp4karnataka anusharavi10 lavanyaballal mondalsudipto shyamsprasad srinualavilli tvmohandaspai yogeeshgp branches tree cutting much extended branches ok modi road
# Predicted Polarity: 0.24379794983263572
# Predicted Sentiment Class: neutral
#
# Tweet: zoobear av pakistan par 24 bomb girega kch log phr saboot mangegemodi condolence nahi action viswas krte
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: aamaadmiparty arvindkejriwal kejariwal pani pipi ke daily gali de raha hai modi ji ko
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: dear hindus watched happened kashmiri pandits kashmir files watched happened hindu girls kerela story support modi else state next file next story sincerely hindu
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: narendramodi modi 90
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: satyaprpati ani modi say kehna 20 30 rupay tum ghareebo main bhi baant de apni trillion dollar economy main su nikal k
# Predicted Polarity: 0.06666883749573466
# Predicted Sentiment Class: neutral
#
# Tweet: nithish07611895 farzicricketer thats still half narendra modi stadium unless statistics prove percentage seats sold pointless argue saw one game poorly performing team indian star players
# Predicted Polarity: -0.1778313316254824
# Predicted Sentiment Class: neutral
#
# Tweet: dennisdacunha
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ssmbswarrior gujarattitans em le modi hai cup hai modi team kada anta script adi inkosari cup kosam
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: coolrajatraj83 swamy39 pgurus1 modis promise sonia amp chiddu
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modi stop genocide kashmir rss hindu terrorists 1000000 indian army
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: huk06 shaykshack munawarshaikh92 agree modi never wanted real sort camaraderie dont agree onus bit well wo us much offer domestic political benefits triumph miniscule economic gains normalisation paxtan bring
# Predicted Polarity: 0.09769924463905585
# Predicted Sentiment Class: neutral
#
# Tweet: anuraagmuskaan modi ke aya tha tm jse chamcha ka pichwada dard ho raha tha
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: audacity pm democratic country doesnt care two hoots even addressing issue still confused love modi vs islamophobia anyways doomed 2024 wd constitution democracy thereby need bhakts either
# Predicted Polarity: 0.4000021714118295
# Predicted Sentiment Class: positive
#
# Tweet: border state modishah arvindkejriwal bhagwantmann border state manipur
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: wrestlers india modi india karnataka jantarmantar trending viral
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: mithilawaala whole country burning maulana modi busy triptikaran
# Predicted Polarity: 0.05961224114639428
# Predicted Sentiment Class: neutral
#
# Tweet: iamsayeedrahman ssaahebup85 anidigital ani modi innocent hai court ke hisaab se
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: iqrachaudhry maine bhi modi ko woh quran kuch padhye dekha hai aur chadar chadhate dekha hai hum log isko kya samjhe
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: kachhawagayatri supriyashrinate nehi madamkhali rahul gandhi nehi lekin jab modi khatre ate hay usko bachane k liye u stand tall till last second election process modi government b thrown next election
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: sharad07077774 nowwakeup1982 incindia rahulgandhi rote raho ayega phir modi hi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: narendramodi hamarapm modi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modi hai mumkin hai sonia hai nischit hai
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: adahsharma modi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: narendramodi manipur modi manipur modi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: hajipurrajesh manojkjhadu newindianxpress themornstandard president also action think respected ram nath murmur r modihm every one know
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ranaayyub forget modiyou tell whats true movie tell us isis doesnt exist tell us single person kerala joined isis tell woman trapped n sent syria serve isis use words n tell
# Predicted Polarity: 0.07349584064571507
# Predicted Sentiment Class: neutral
#
# Tweet: balfaqih abdllhb
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: syedfofficial narendramodi dont worry expenses dude concentrate modi ji says
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: rssurjewala see frustration due modi wave across burnol moment
# Predicted Polarity: -0.024997829331191528
# Predicted Sentiment Class: neutral
#
# Tweet: balfaqih modih1
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: unityjat modihataodeshbachao
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: loksattalive modi half brutal hitler prakashraaj would got umbrella opened inside
# Predicted Polarity: -0.40888685613971987
# Predicted Sentiment Class: negative
#
# Tweet: vishaalofficial deependershooda tu bjp k chat le tere jise na ya halat krwa di gobar khan lenge aayega modi hi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: normies give cover wackos many boring normal fams hanuman chalisa puja hanumanday tuesday also gobble modis bullshit aaj tak fearmongering etc
# Predicted Polarity: 0.4000021714118297
# Predicted Sentiment Class: positive
#
# Tweet: upblissed narendramodi looks like monkey modi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: bharatvarsh modi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: zubinashara narendramodi bjp4india bjp4gujarat jpnadda mansukhmandviya crpaatil pradipsinhbjp ratnakar273 amitshah obama spoke better english modi obamacare wins
# Predicted Polarity: 0.2924412181514221
# Predicted Sentiment Class: neutral
#
# Tweet: narendramodi manipur modi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modi kejriwal cm arvindkejriwal
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modi stop genocide kashmir rss hindu terrorists 1000000 indian army
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: live pok pm modi pakistan pm shehbaz sharif pakistan crisis news18 uttarakhand
# Predicted Polarity: 0.036129064715069964
# Predicted Sentiment Class: neutral
#
# Tweet: mp politics abp
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: bitt2da godgiftnamo jhuk kar modi ji ke pair pado
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: skanth sir make post congress 5 promises vs modi 5 cry 91 times hanuman kerala story etc
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: immak02 netflix series caliphate made sweden link modi rss h
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: nytimes brought modis amp bjps amp radical hindu name type journalism
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: sudhanshubjp narendramodi modi ji great hero
# Predicted Polarity: 0.699890564793264
# Predicted Sentiment Class: positive
#
# Tweet: manishs80221272 swamy39 pgurus1 modi hai mumkin hai sonia hai nischit hai
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: narendra modi ne pura desh ko barbad kar diya udyogpatiyon ke sare per apna akal na hone per
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: modi kerala story terrorism congress brilliance modi ji blueprint fool proof
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: aartitikoo newstrader modi called
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: tweetcheckindia swamy39 pgurus1 get lost modi bhakt cheating tax payers
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: anr4dalits usual playbook victory credit modi defeat riots andor create diversion story
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: tequieremos paymasters sell pakistan right price modi fight pak generals bought million dollars
# Predicted Polarity: 0.18564205198944797
# Predicted Sentiment Class: neutral
#
# Tweet: another modi propaganda movie full guess whatlies
# Predicted Polarity: 0.12220787548965521
# Predicted Sentiment Class: neutral
#
# Tweet: tivary first kiran flush well dont shit everywhere tempered non capabilities last benchers modi ministers
# Predicted Polarity: 0.016706589605896625
# Predicted Sentiment Class: neutral
#
# Tweet: modi kejriwal cm arvindkejriwal
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: swamy39 appears tdk continues hold strong control modi govt like mms govt miracle managed drag amp buddhu son court got arrested made apply bail achieve unachievable things india powers dr swamy
# Predicted Polarity: 0.16267154660602737
# Predicted Sentiment Class: neutral
#
# Tweet: ezra666
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: amirmateen2 bbhuttozardari best ways respond amp slap 1 release audio video 2 gift plots dha commercial plots 3 invite modi like bajwa amp best brains decided 4 file new case imran khan hafiz amp nadeem furious still pray war company ghusa
# Predicted Polarity: 0.6993957217598791
# Predicted Sentiment Class: positive
#
# Tweet: hindsresth boltahindustan kya modi ji ko bajrang dal aur bajrang bali antar nahi padta baat bajrang dal ki ho rhi hai wo rajnitik fayade k liye bajrang bali ko le aaye
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ayushmanngenius akkumodi optionables vihan13singh like terms conditions
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: abhijeetdipke wish life modi winning 2024 grand 350 seats retires actually teach definition fascism dogs like
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: sallugooner yes 2019 2022 5 mins stopped trade india us ran successful campaign modi 5 mins dad removed bring bbz ik refused sell kashmir
# Predicted Polarity: 0.6505230051831459
# Predicted Sentiment Class: positive
#
# Tweet: tejaswisurya narendramodi karnatakaelection2023 karnatakaelectionnews tejasvisurya narendramodi
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: girishvivian know riots 2002 modis roll egging know beatings muslim men street know government sanctioned destruction mosques know modis participation hate groups
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: bandisanjaybjp saalu modi sampaku modipaid artists latho shoot chesi thambaku
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: prakashraaj paisa laga hai bhai jaise aap apni picture promote karte ho tab modi ji kuch kehte hain kya
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: fawadchaudhry love modi
# Predicted Polarity: 0.4000021714118295
# Predicted Sentiment Class: positive
#
# Tweet: tivary jai bajrang bali modi winning stay calm keep quiet
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: farzi kashmiri files ke baad kerala story farzi fake film bjp sanghi sab prachar karne lage posters lagane lage modi bhi prachar karne laga
# Predicted Polarity: -0.3999978299867992
# Predicted Sentiment Class: negative
#
# Tweet: modi save anyone
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: timesnow 1sahid afridi free say whatever wants land 2 views pakistans views 3 modi pm india pak 4 ar really reporting news running news wonder indias rank press low shameless
# Predicted Polarity: 0.16914856999771818
# Predicted Sentiment Class: neutral
#
# Tweet: karnataka elections pm modi takes massive roadshow bengaluru today
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: khawajamasif khawaja masif want bend modi thats choice dont fckin embarrass us
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# ...
# Predicted Polarity: -0.30010943695502335
# Predicted Sentiment Class: neutral
#
# Tweet: nice theyre crossing illegally get put fancy hotels bad trudeau hasnt got money vets theyve earned
# Predicted Polarity: -0.17006334092095013
# Predicted Sentiment Class: neutral
#
# Tweet: speaker house must go every time someone speaks trudeau liberals always goes stands liberals
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: ecochrane1889 otohp thehilltimes katemalloy379 harrisauthor father hated pierre trudeau probably handsome appealed men women called phony intellectual full laugh see complaints new generation insecure men justin trudeau
# Predicted Polarity: 0.16457197026886153
# Predicted Sentiment Class: neutral
#
# Tweet: theinternet14 cp24 nothing one million immigrants trudeau keep country afloat leftist attacks
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: denisebatters sgirardau contrary trudeau said beyond obvious justin trudeau hates conservative canadians much willing let china threaten family conservative mp glad benefit chinas interference electoral benefit
# Predicted Polarity: 0.10000217088734392
# Predicted Sentiment Class: neutral
#
# Tweet: stonesculptorjn give pm much credit could come idea analyze anything people around definitely shape words ideas hes face hair albeit one doesnt realize tin man readers comments
# Predicted Polarity: 0.10000217088734392
# Predicted Sentiment Class: neutral
#
# Tweet: well course lied name trudeau trudeauchineseasset
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: wendel44680353 mythiasm globepolitics prime minister justin trudeau continues maintain threats beijing conservative mp michael chong family never made political level office two years ago
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: davidakin justintrudeau women get many ideas crush still call feminist trudeau win every time
# Predicted Polarity: 0.535621366837382
# Predicted Sentiment Class: positive
#
# Tweet: cherielle100 justin trudeau et sa rcriture de lhistoire de sa gestion covid redfinir lhistoire en la modifiant pour quelle corresponde son ide est pas la vrit historique que lon retrouve dans tous ces discours et vidos
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: stablesvalerie justintrudeau ahhhh fordnation blaming trudeau provinces high cost rent mortgages crossed corporate fleeting farmers saw price 1 cauliflower week 900 3 weeks ago store cauliflower location 275 1 hard blame pm
# Predicted Polarity: -0.06351603178553514
# Predicted Sentiment Class: neutral
#
# Tweet: senator exposes trudeaus latest scandal
# Predicted Polarity: 0.40000217141183003
# Predicted Sentiment Class: positive
#
# Tweet: let prime minister trudeau minister murray government canada know stand indigenous communities asserting inherent rights call end shutdown bc salmon farms salmonfarming aquaculture reconciliation
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: moreauagathe3 justin trudeau et sa rcriture de lhistoire de sa gestion covid redfinir lhistoire en la modifiant pour quelle corresponde son ide est pas la vrit historique que lon retrouve dans tous ces discours et vidos
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: gmbutts trudeaus pal talking breaking laws hysterical policies fear definitely speaking experience much paying live trudeaus office couch anyway
# Predicted Polarity: 0.06679817851167041
# Predicted Sentiment Class: neutral
#
# Tweet: therealkeean trudeaus appointed csis director damage control backstopping china intel reason csis staffers job forced go around leak important national security intel stop escalating corruption foreign interference
# Predicted Polarity: 0.025244056567714553
# Predicted Sentiment Class: neutral
#
# Tweet: seamusoregan liberalparty ylcjlc sachitmehra telfordk oh dear fit trudeau supporters one room
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: andrewscheer probably sponsored come blame trudeau
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: trump dit grab pussy la plante sinsurgent comme des animaux sauvage mais l trudeau lui cest pas grave ont passe lponge mer au mdia subventionn de te manger lcul trudeau agresseur justin
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: liberalparty trudeau lying thief sack crap
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: rachelpenseque justin trudeau et sa rcriture de lhistoire de sa gestion covid redfinir lhistoire en la modifiant pour quelle corresponde son ide est pas la vrit historique que lon retrouve dans tous ces discours et vidos
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: cp24 trudeaus canada
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: liberalparty youre comedian trudeau
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: dsjost torontostar chantalhbert watching online 106 people seats nearly empty speakers trudeau came
# Predicted Polarity: 0.021356337416515447
# Predicted Sentiment Class: neutral
#
# Tweet: perfectly describes trudeaus latest attempt deny responsibility directly ruining lives millions canadians lies unjust covid mandates
# Predicted Polarity: 0.40000217141183003
# Predicted Sentiment Class: positive
#
# Tweet: motomom128302 justintrudeau trudeau good debating 16 year olds
# Predicted Polarity: 0.6002625884286094
# Predicted Sentiment Class: positive
#
# Tweet: liberalparty trudeau cant say fact new canadian flag canada trudeau fucktrudeau lpc lpc2023 lib2023
# Predicted Polarity: 0.036129064715069964
# Predicted Sentiment Class: neutral
#
# Tweet: wearecanproud proven blatant lie never allowed parliament like trudeau lie want public looses even trust system children disciplined lying leaders canada lie want totally immoral illogical
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: princes35964114 susandelacourt contrary trudeau said beyond obvious justin trudeau hates conservative canadians much willing let china threaten family conservative mp glad benefit chinas interference electoral benefit
# Predicted Polarity: 0.10000217088734392
# Predicted Sentiment Class: neutral
#
# Tweet: cowlestommy trudeau
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: trudeau cant say fact new canadian flag canada trudeau fucktrudeau lpc lpc2023 lib2023
# Predicted Polarity: 0.036129064715069964
# Predicted Sentiment Class: neutral
#
# Tweet: andrewpatriot trumplar liberal trudeau drug cartel crtc ban fox broadcasting canada
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: captaincoby00 trudeau uniting canadians utter nonsense jt doesnt even know meaning word
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: arrivou krismeloche false information inflation caused trudeaus massive taxation spending jobs created government subsidize jobs theyre real jobs sustainable 14 billion last month another corporate friendvw
# Predicted Polarity: -0.09687382863609216
# Predicted Sentiment Class: neutral
#
# Tweet: thehilltimes harrisauthor somebody hold trudeau accountable conservatives great job letting trudeau know useless pm canadians enough
# Predicted Polarity: 0.14645712383309809
# Predicted Sentiment Class: neutral
#
# Tweet: normanlevine100 markgerretsen nationalpost proof dirty desperate gov mr chong stellar unimpeachable reputation liberals know cdns reminded dirty trudeau libs would rather besmirch good mans reputation deport filthy prc agent ca
# Predicted Polarity: -0.17504283156047604
# Predicted Sentiment Class: neutral
#
# Tweet: walterpq66 brianlilley justintrudeau michaelchongmp ashamed nancyi would supporting ethics violations lies embarrassments bad treatment femalesamp putting country much debt doesnt make trudeau liberal supporters look good trudeaumustgo liberalsmustgo
# Predicted Polarity: 0.06556316171569015
# Predicted Sentiment Class: neutral
#
# Tweet: fuck justin trudeau
# Predicted Polarity: -0.2999978298119711
# Predicted Sentiment Class: neutral
#
# Tweet: globepolitics jenniferelle canada deserves better trudeau liberals
# Predicted Polarity: 0.4000021714118297
# Predicted Sentiment Class: positive
#
# Tweet: gemstercasey1 acts cbc shit groper mchappy hands trudeau fan
# Predicted Polarity: -0.09999782946231338
# Predicted Sentiment Class: neutral
#
# Tweet: pairmobile ambermac jeffwaldmanhr justintrudeau pierrepoilievre ya trudeau great job declining standard living acceptable liberals please explain understand
# Predicted Polarity: 0.699890564793264
# Predicted Sentiment Class: positive
#
# Tweet: mya11281477 pierrepoilievre would like see boxing match trudeau well big mouth senator last boxing match justintrudeau pierrepoilievre lets raise money charity
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: canadians want know nybased investors canadian media organs directing canadian journalists reporters promote antigovernment antitrudeau stories whether true order destabilize canadian government
# Predicted Polarity: 0.24989800448273816
# Predicted Sentiment Class: neutral
#
# Tweet: macpropane billboardchris yes coming top police command ultimately trudeau
# Predicted Polarity: 0.4000021714118299
# Predicted Sentiment Class: positive
#
# Tweet: cpactv um shouldnt video taken misinformation given justin trudeau lives clouds world seeing truth going canada
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: govtcorrupt davidjmcwalter trudeau deeply injured canadas freedoms reputation destroy canada
# Predicted Polarity: -0.09999782946231338
# Predicted Sentiment Class: neutral
#
# Tweet: thebreakdownab deep red must trudeaus fault right right
# Predicted Polarity: 0.18564205198944797
# Predicted Sentiment Class: neutral
#
# Tweet: wildcatio justintrudeau supposed swim england head canada commonwealth nation issue trudeau plenty chose
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: shoochoux clareblackwood cbc actress major groper mchappy hands trudeau fan
# Predicted Polarity: 0.021356337416515447
# Predicted Sentiment Class: neutral
#
# Tweet: jtloveshimself7 blackface trudeau
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: burt642 hasnt trudeau charged treason yet
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: globalcalgary pathetic media outlet spin good news smear people inproving healthcare promote people harmed global needs trudeau give taxpayer money lie notley abpoli ableg cdnmediafailed canadian media corrupt trudeau
# Predicted Polarity: -0.2189185558331733
# Predicted Sentiment Class: neutral
#
# Tweet: il est claire maintenant que trudeau tente dembrouiller les cerveaux des plus simplets en rinventant une toute autre histoire de lobligation vaccinale
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: iwwtsportsdata caseyho46088134 graymackenzie mostly trudeau reason would cpc lying nothing cover
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: torontostar chantalhbert lol written trudeau foundation minion online 107 people watching vast majority seats empty jt came negative speech opposition bad shit talk cons nothing positive
# Predicted Polarity: -0.3399212699928099
# Predicted Sentiment Class: neutral
#
# Tweet: chinaembottawa ambassador leave guy place canada hes disrespectful trudeau must act send 48 hours notice doesnt confirm jt ccp payroll
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: world recognizes authoritarian leadership canada trudeau embarrassment
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: pierrepoilievre get us back canada trudeaus chinada ochinada
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: cp24 contrary trudeau said beyond obvious justin trudeau hates conservative canadians much willing let china threaten family conservative mp glad benefit chinas interference electoral benefit
# Predicted Polarity: 0.10000217088734392
# Predicted Sentiment Class: neutral
#
# Tweet: sushihunter2 recent resignation announcement new zealand prime minister jacinda ardern prompted guardian wonder whether trudeau enough left tank fight another election john ivison
# Predicted Polarity: 0.036129064715069964
# Predicted Sentiment Class: neutral
#
# Tweet: cpactv trudeau liberals proven real leadership one worst times canadas history pandemic kept canada strong continues
# Predicted Polarity: -0.13999449107321774
# Predicted Sentiment Class: neutral
#
# Tweet: interesting see canadas role coronation tomorrowwill justin trudeau process white tie pms commonwealth realms louis stlaurent 1953
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: elizabe82475682 conservative says trudeau wrecked country unemployment rate canada 5 fifth consecutive month april 2023 remaining close recordlow 49 observed june july 2022
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: two photos real justin trudeau two
# Predicted Polarity: 0.09965494866451502
# Predicted Sentiment Class: neutral
#
# Tweet: duncandee bryanpassifiume time speaker house demand mps answer questions censure lying liberals including trudeau nonconfidence
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: dkreative1 recent resignation announcement new zealand prime minister jacinda ardern prompted guardian wonder whether trudeau enough left tank fight another election john ivison
# Predicted Polarity: 0.036129064715069964
# Predicted Sentiment Class: neutral
#
# Tweet: palalaland ambermac jeffwaldmanhr justintrudeau pierrepoilievre ya pierre feminist like trudeau
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: hollyanndoan cafreeland hillaryclinton quid pro quo trudeau foundation donates clinton foundation versa lets continue launder together
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: justintrudeau oh also hear trudeau amp chuckie cousins removed
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: brianlilley kikafreeze sounds looks like trudeau wants erase canadas historical symbols along canadian people
# Predicted Polarity: 0.09965494866451502
# Predicted Sentiment Class: neutral
#
# Tweet: mcfarlaneglenda recent resignation announcement new zealand prime minister jacinda ardern prompted guardian wonder whether trudeau enough left tank fight another election john ivison
# Predicted Polarity: 0.036129064715069964
# Predicted Sentiment Class: neutral
#
# Tweet: thank truanons voted twice three times corrupt pm justintrudeau lifetime includes second corrupt father pierre elliott trudeau
# Predicted Polarity: -0.3999978299868001
# Predicted Sentiment Class: negative
#
# Tweet: connordpeters traitor trudeau corrupt lying bully trudeau bring election
# Predicted Polarity: -0.3999978299868001
# Predicted Sentiment Class: negative
#
# Tweet: francis4hamelin patriciam74 pcchq cpchq pierrepoilievre voter par conviction napporte jamais de regrets contrairement voter pour le faible sheer woke otoole ou prochainement pp qui prend les mmes positions que trudeau sur les enjeux mentionns
# Predicted Polarity: 0.021356337416514895
# Predicted Sentiment Class: neutral
#
# Tweet: rebelnewsonline trudeau ahhh shutup sick
# Predicted Polarity: -0.6143579494091814
# Predicted Sentiment Class: negative
#
# Tweet: taleeb justintrudeau canadianpm trudeau live prick caused record inflation destroying canada
# Predicted Polarity: -0.030524551033879282
# Predicted Sentiment Class: neutral

# %%
# Calculate the true sentiment classes for the Modi and Trudeau tweets
modi_true_classes = [polarity_to_class(TextBlob(tweet).sentiment.polarity) for tweet in modi_tweets]
trudeau_true_classes = [polarity_to_class(TextBlob(tweet).sentiment.polarity) for tweet in trudeau_tweets]

# Create a binary feature matrix for the Modi and Trudeau tweets
X_test = vectorizer.transform(pd.concat([modi_tweets, trudeau_tweets], ignore_index=True)).toarray()

# Predict sentiment polarity of the Modi and Trudeau tweets
y_pred = model.predict(X_test)

# Convert the predicted polarity values to sentiment classes
y_pred_classes = [polarity_to_class(polarity) for polarity in y_pred]

# Calculate the accuracy and classification report
accuracy = accuracy_score(modi_true_classes + trudeau_true_classes, y_pred_classes)
print("Accuracy:", accuracy)
report = classification_report(modi_true_classes + trudeau_true_classes, y_pred_classes)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.8942992874109263
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.65      0.60      0.62        47
#      neutral       0.92      0.95      0.94       707
#     positive       0.73      0.59      0.65        88
#
#     accuracy                           0.89       842
#    macro avg       0.77      0.71      0.74       842
# weighted avg       0.89      0.89      0.89       842

# %%
#For comparison to actual polarity

# Calculate the number of tweets for each leader
num_modi_tweets = len(modi_tweets)
num_trudeau_tweets = len(trudeau_tweets)

# Slice the y_pred array into two separate arrays for Modi and Trudeau
modi_pred_polarities = y_pred[:num_modi_tweets]
trudeau_pred_polarities = y_pred[num_modi_tweets:]

# Calculate the average polarity score for Modi and Trudeau
modi_avg_polarity = modi_pred_polarities.mean()
trudeau_avg_polarity = trudeau_pred_polarities.mean()

# Print the average polarity scores
print(f"Modi's Average Polarity Score: {modi_avg_polarity}")
print(f"Trudeau's Average Polarity Score: {trudeau_avg_polarity}")
# Out:
# Modi's Average Polarity Score: 0.06323040590950363
# Trudeau's Average Polarity Score: 0.02153289336897309
